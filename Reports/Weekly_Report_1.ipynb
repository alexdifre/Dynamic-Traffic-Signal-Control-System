# %% [markdown]
# # Weekly Report 1
#
# ## What did I do this week?
# This week I focused on setting up the development environment and understanding the project structure. I explored the trafficSimulator repository (BilHim/trafficSimulator) to understand how the traffic simulation works. I used ChatGPT to help clarify some concepts about the simulator's API and how to properly interface with it. I also set up the basic project structure with the necessary directories and initial configuration files.
#
# ## How has the program progressed?
# The program is in its initial setup phase. I have successfully:
# - Cloned and explored the traffic simulator repository
# - Created the basic project structure with folders for reinforcement learning code, documentation, and tests
# - Understood the simulator's state representation (traffic signal phases, vehicle counts, lane configurations)
#
# ## What did I learn this week/today?
# I learned how the traffic simulator represents intersections and manages vehicle flow. Specifically:
# - How the simulator tracks vehicles in different lanes
# - The state representation including signal phases and queue lengths
# - How to initialize a two-way intersection simulation
# - The basic workflow of running simulation steps and extracting observations
#
#
# ## What remains unclear or has been challenging?
# I'm still uncertain about:
# - The exact reward function design - should I penalize long queues or reward queue reduction?
# - How to handle the transition between traffic light phases (minimum green time, yellow light duration)
# - The optimal state space representation - should I include more features like waiting times or keep it simple?
# - How many vehicles to spawn and what traffic patterns to use for realistic training
#
# ## What will I do next?
# Next week I will:
# - Implement the Environment wrapper class that interfaces with the traffic simulator
# - Create the basic Q-learning agent class with the Q-table structure
# - Test the environment-simulator integration to ensure state observations are correct
# - Start thinking about hyperparameter choices (learning rate, discount factor, epsilon)
#
# Chatgpt was used for rewriting in a clearly and correctly way  the concepts illustrated in this weekly report.
#
# ---
#
# **Hours logged this week:** 12 hours
