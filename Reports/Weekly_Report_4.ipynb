# %% [markdown]
# # Weekly Report 4
#
# ## What did I do this week?
# This week I focused on hyperparameter optimization to improve the agent's learning performance. I implemented a systematic grid search to find the optimal combination of learning rate (ALPHA), discount factor (GAMMA), and initial exploration rate (EPSILON), while keeping EPSILON_MIN = 0.01 and EPSILON_DECAY = 0.995 constant. I ran multiple training sessions with different parameter combinations and evaluated each configuration based on average reward.
#
# ## How has the program progressed?
# The program has improved through hyperparameter tuning. I have :
# - Implemented grid search functionality to test multiple parameter combinations
# - Tested 12 different configurations (3 values for each of ALPHA, 2 for GAMMA and EPSILON)
# - Identified the optimal configuration: ALPHA = 0.15, GAMMA = 0.5, EPSILON = 0.1
# - Validated the results across multiple independent training runs
# - performance improvements: 7.6% reduction in average reward
#
#
# ## What did I learn this week/today?
# I learned important lessons about hyperparameter optimization in reinforcement learning:
# - **Learning rate impact**: Higher learning rates caused instability, while lower rates (α < 0.03) learned too slowly
# - **Initial exploration importance**: Starting with ε = 0.1 allowed sufficient early exploration before the decay reduced it
#
#
# ## What remains unclear or has been challenging?
# Some challenges I encountered during hyperparameter tuning:
# - **Local optima**: I'm not certain if the current configuration is globally optimal or just locally optimal within my search space
# - **Parameter interactions**: Understanding why certain combinations work better than others is not always intuitive
#
# I'm also uncertain whether I should expand the search space (test more values) or if the current configuration is sufficient for this project.
#
# ## What will I do next?
# Next week I will:
# - I  write the test algorithms for the Reinforcement Learning (RL) section, following the guidelines provided by my instructors
#
#
# ChatGPT was used for rewriting in a more clearly and correctly way the concepts illustrated in this weekly report.
#
# ---
#
# **Hours logged this week:** 6 hours
